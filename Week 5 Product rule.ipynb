# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sympy as sy
from sympy import diff, exp, Symbol, cos, sin, log

# %%
x = Symbol('x')
def f(x):return (2*x+1)**3*(x-1)**4
sy.simplify(f(x))
# Out:
# (x - 1)**4*(2*x + 1)**3

# %%
print('df=', sy.diff(f(x)))
# Out:
# df= 6*(x - 1)**4*(2*x + 1)**2 + 4*(x - 1)**3*(2*x + 1)**3

# %%
sy.simplify(sy.diff(f(x)))
# Out:
# (x - 1)**3*(2*x + 1)**2*(14*x - 2)

# %%
def f(y): return (x**2+3)**-1
y=Symbol('y')
sy.simplify(sy.diff(f(y)))
# Out:
# -2*x/(x**2 + 3)**2
