# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/VGSales.csv")

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16595.000000  16595.000000  16596.000000
# mean    8300.605254   2006.406443      0.262117      0.145240      0.077593
# std     4791.853933      5.828981      0.778219      0.488419      0.308308
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16595.000000  16595.000000
# mean       0.047969      0.534388
# std        0.188390      1.528897
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
df.describe(include='all')
# Out:
#                 Rank                         Name Platform          Year  \
# count   16598.000000                        16598    16598  16327.000000
# unique           NaN                        11493       31           NaN
# top              NaN  Need for Speed: Most Wanted       DS           NaN
# freq             NaN                           12     2163           NaN
# mean     8300.605254                          NaN      NaN   2006.406443
# std      4791.853933                          NaN      NaN      5.828981
# min         1.000000                          NaN      NaN   1980.000000
# 25%      4151.250000                          NaN      NaN   2003.000000
# 50%      8300.500000                          NaN      NaN   2007.000000
# 75%     12449.750000                          NaN      NaN   2010.000000
# max     16600.000000                          NaN      NaN   2020.000000
#
#          Genre        Publisher      NA_Sales      EU_Sales      JP_Sales  \
# count    16598            16540  16595.000000  16595.000000  16596.000000
# unique      12              578           NaN           NaN           NaN
# top     Action  Electronic Arts           NaN           NaN           NaN
# freq      3316             1351           NaN           NaN           NaN
# mean       NaN              NaN      0.262117      0.145240      0.077593
# std        NaN              NaN      0.778219      0.488419      0.308308
# min        NaN              NaN      0.000000      0.000000      0.000000
# 25%        NaN              NaN      0.000000      0.000000      0.000000
# 50%        NaN              NaN      0.080000      0.020000      0.000000
# 75%        NaN              NaN      0.240000      0.110000      0.040000
# max        NaN              NaN     41.490000     29.020000     10.220000
#
#          Other_Sales  Global_Sales
# count   16595.000000  16595.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean        0.047969      0.534388
# std         0.188390      1.528897
# min         0.000000      0.010000
# 25%         0.000000      0.060000
# 50%         0.010000      0.170000
# 75%         0.040000      0.470000
# max        10.570000     82.740000

# %%
df.info()

# %%
df.head(10)

# %%
df.isna()

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          3
# EU_Sales          3
# JP_Sales          2
# Other_Sales       3
# Global_Sales      3
# dtype: int64

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(343)

# %%
df.isnull().sum()/ df.size * 100
# Out:
# Rank            0.000000
# Name            0.000000
# Platform        0.000000
# Year            0.148430
# Genre           0.000000
# Publisher       0.031767
# NA_Sales        0.001643
# EU_Sales        0.001643
# JP_Sales        0.001095
# Other_Sales     0.001643
# Global_Sales    0.001643
# dtype: float64

# %%
df2=df.copy

# %%
df1=df.copy(deep=True)

# %%
#df2.isnull(how='any')

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.
